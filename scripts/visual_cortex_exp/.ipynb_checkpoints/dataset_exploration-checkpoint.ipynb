# %%
import pandas as pd
import scipy.io
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# 01.mat                            crcns_pvc-8_data_description.pdf
# 02.mat                            dataset_exploration.ipynb
# coen-cagli2015.pdf                filelist.txt
# crcns_pvc-8_data_description.docx main_LoadAndParse.m

# %%
dataset = scipy.io.loadmat('01.mat')

# %%
stimulus = dataset['images']

# %%
stimulus[0][0].shape
# Out:
# (320, 320)

# %%
sample_stimulus = stimulus[0][3]

# %%
plt.figure()
plt.imshow(sample_stimulus, cmap = 'gray')
plt.title('Sample stimulus displayed to anasthesized rat')
# Out:
# Text(0.5, 1.0, 'Sample stimulus displayed to anasthesized rat')
